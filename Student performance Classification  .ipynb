# %% [markdown]
# ## Import Liabiaries

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt  
import warnings 
warnings.filterwarnings("ignore")

# %%
student = pd.read_csv(r"C:\Users\Lenovo\Downloads\xAPI-Edu-Data.csv")
student
# Out:
#     gender       StageID SectionID Relation Semester      Topic  raisedhands  \
# 0        M    lowerlevel         A   Father        F         IT           15
# 1        M    lowerlevel         A   Father        F         IT           20
# 2        M    lowerlevel         A   Father        F         IT           10
# 3        M    lowerlevel         A   Father        F         IT           30
# 4        M    lowerlevel         A   Father        F         IT           40
# ..     ...           ...       ...      ...      ...        ...          ...
# 475      F  MiddleSchool         A   Father        S  Chemistry            5
# 476      F  MiddleSchool         A   Father        F    Geology           50
# 477      F  MiddleSchool         A   Father        S    Geology           55
# 478      F  MiddleSchool         A   Father        F    History           30
# 479      F  MiddleSchool         A   Father        S    History           35
#
# ...

# %%
# Data overwview 
student.describe(include = "all")
# Out:
#        gender       StageID SectionID Relation Semester Topic  raisedhands  \
# count     480           480       480      480      480   480   480.000000
# unique      2             3         3        2        2    12          NaN
# top         M  MiddleSchool         A   Father        F    IT          NaN
# freq      305           248       283      283      245    95          NaN
# mean      NaN           NaN       NaN      NaN      NaN   NaN    46.775000
# std       NaN           NaN       NaN      NaN      NaN   NaN    30.779223
# min       NaN           NaN       NaN      NaN      NaN   NaN     0.000000
# 25%       NaN           NaN       NaN      NaN      NaN   NaN    15.750000
# 50%       NaN           NaN       NaN      NaN      NaN   NaN    50.000000
# 75%       NaN           NaN       NaN      NaN      NaN   NaN    75.000000
# max       NaN           NaN       NaN      NaN      NaN   NaN   100.000000
#
#         VisITedResources  AnnouncementsView  Discussion  \
# ...

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   StageID                   480 non-null    object
#  2   SectionID                 480 non-null    object
#  3   Relation                  480 non-null    object
#  4   Semester                  480 non-null    object
#  5   Topic                     480 non-null    object
#  6   raisedhands               480 non-null    int64
#  7   VisITedResources          480 non-null    int64
#  8   AnnouncementsView         480 non-null    int64
#  9   Discussion                480 non-null    int64
#  10  ParentschoolSatisfaction  480 non-null    object
#  11  StudentAbsenceDays        480 non-null    object
#  12  Class                     480 non-null    object
# dtypes: int64(4), object(9)
# memory usage: 48.9+ KB

# %%
student.isnull().sum()
# Out:
# gender                      0
# StageID                     0
# SectionID                   0
# Relation                    0
# Semester                    0
# Topic                       0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
for i in student.columns:
    print({i:student[i].unique()})
# Out:
# {'gender': array(['M', 'F'], dtype=object)}
# {'StageID': array(['lowerlevel', 'MiddleSchool', 'HighSchool'], dtype=object)}
# {'SectionID': array(['A', 'B', 'C'], dtype=object)}
# {'Relation': array(['Father', 'Mum'], dtype=object)}
# {'Semester': array(['F', 'S'], dtype=object)}
# {'Topic': array(['IT', 'Math', 'Arabic', 'Science', 'English', 'Quran', 'Spanish',
#        'French', 'History', 'Biology', 'Chemistry', 'Geology'],
#       dtype=object)}
# {'raisedhands': array([ 15,  20,  10,  30,  40,  42,  35,  50,  12,  70,  19,   5,  62,
#         36,  55,  69,  60,   2,   0,   8,  25,  75,   4,  45,  14,  33,
#          7,  13,  29,  39,  49,  16,  28,  27,  21,  80,  17,  65,  22,
#         11,   1,   3, 100,   6,  90,  77,  24,  66,  23,  82,  72,  51,
#         85,  87,  95,  81,  53,  92,  83,  67,  96,  57,  73,   9,  32,
#         52,  59,  61,  79,  18,  74,  97,  41,  71,  98,  78,  89,  88,
#         86,  76,  99,  84])}
# ...

# %%
student.Topic.value_counts()
# Out:
# Topic
# IT           95
# French       65
# Arabic       59
# Science      51
# English      45
# Biology      30
# Spanish      25
# Geology      24
# Chemistry    24
# Quran        22
# Math         21
# History      19
# Name: count, dtype: int64

# %%
student["Institute"] = "XYZ"
student
# Out:
#     gender       StageID SectionID Relation Semester      Topic  raisedhands  \
# 0        M    lowerlevel         A   Father        F         IT           15
# 1        M    lowerlevel         A   Father        F         IT           20
# 2        M    lowerlevel         A   Father        F         IT           10
# 3        M    lowerlevel         A   Father        F         IT           30
# 4        M    lowerlevel         A   Father        F         IT           40
# ..     ...           ...       ...      ...      ...        ...          ...
# 475      F  MiddleSchool         A   Father        S  Chemistry            5
# 476      F  MiddleSchool         A   Father        F    Geology           50
# 477      F  MiddleSchool         A   Father        S    Geology           55
# 478      F  MiddleSchool         A   Father        F    History           30
# 479      F  MiddleSchool         A   Father        S    History           35
#
# ...

# %% [markdown]
# ## Feature Selection

# %%
student.columns
# Out:
# Index(['gender', 'StageID', 'SectionID', 'Relation', 'Semester', 'Topic',
#        'raisedhands', 'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentschoolSatisfaction', 'StudentAbsenceDays', 'Class', 'Institute'],
#       dtype='object')

# %%
### Droping Institute columns as it has singularity 
student.drop(["Institute"],axis =1 ,inplace = True )

# %%
student
# Out:
#     gender       StageID SectionID Relation Semester      Topic  raisedhands  \
# 0        M    lowerlevel         A   Father        F         IT           15
# 1        M    lowerlevel         A   Father        F         IT           20
# 2        M    lowerlevel         A   Father        F         IT           10
# 3        M    lowerlevel         A   Father        F         IT           30
# 4        M    lowerlevel         A   Father        F         IT           40
# ..     ...           ...       ...      ...      ...        ...          ...
# 475      F  MiddleSchool         A   Father        S  Chemistry            5
# 476      F  MiddleSchool         A   Father        F    Geology           50
# 477      F  MiddleSchool         A   Father        S    Geology           55
# 478      F  MiddleSchool         A   Father        F    History           30
# 479      F  MiddleSchool         A   Father        S    History           35
#
# ...

# %%
## EDA

# %%
student.dtypes
# Out:
# gender                      object
# StageID                     object
# SectionID                   object
# Relation                    object
# Semester                    object
# Topic                       object
# raisedhands                  int64
# VisITedResources             int64
# AnnouncementsView            int64
# Discussion                   int64
# ParentschoolSatisfaction    object
# StudentAbsenceDays          object
# Class                       object
# dtype: object

# %%
student.hist(figsize=(15,7));

# %% [markdown]
# In the above histogram X-axis defines the frequency number of a student's activity on a particular atribute
# and  Y-axis define the count . The Histogram show that -
# 1. Majoriity students perform visting resources .
# 2. Majority of the students are less eager to view Announcements & to discuss in group
# 3. An average situtaion aries in case of the hand rasing. It seems students have a mixed interest in rasing the hand in class

# %%
student.columns
# Out:
# Index(['gender', 'StageID', 'SectionID', 'Relation', 'Semester', 'Topic',
#        'raisedhands', 'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentschoolSatisfaction', 'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
feature = [ 'raisedhands', 'VisITedResources', 'AnnouncementsView', 'Discussion']

# %%
sns.pairplot(x_vars=feature , y_vars= feature, data = student ,hue = "Class") ;

# %% [markdown]
# From the above pair plot it is quite a lot clear to see that High and low level students are distinguishable in eery combination
# of pair plot but medium level students are scattered in almost everywhere and mixed up both High and Low level student

# %% [markdown]
# # Visulization of Catagorical Data

# %%
sns.countplot(data = student, x = 'gender', hue = 'Class', palette = 'viridis') ;

# %% [markdown]
# Though the number of male Students is greater than the female but the percwntage of High-level students are less than female students
# on the other hand, low-level students in the male are quite a lot greater than the female students

# %%
sns.countplot(data = student, x = 'Relation', hue = 'Class', palette ='Set1');

# %% [markdown]
# It seems to have relationship with Mum has a very positive impact on students performance

# %%
sns.countplot(data =student, x = 'StudentAbsenceDays', hue = 'Class', palette = 'Set1');

# %% [markdown]
# The above picture clearly states that the student who is absent less than  7 days is mostly the Sucessful one . It means Students absence has a High impact on their overall performance

# %%
student.isnull().sum()
# Out:
# gender                      0
# StageID                     0
# SectionID                   0
# Relation                    0
# Semester                    0
# Topic                       0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
student.Class.value_counts()
# Out:
# Class
# M    211
# H    142
# L    127
# Name: count, dtype: int64

# %%
sns.countplot(data = student, x = 'Class', palette = 'pastel');

# %%
colname=[]
for x in student.columns:
    if student[x].dtype=='object':
        colname.append(x)
colname
# Out:
# ['gender',
#  'StageID',
#  'SectionID',
#  'Relation',
#  'Semester',
#  'Topic',
#  'ParentschoolSatisfaction',
#  'StudentAbsenceDays',
#  'Class']

# %%
from sklearn.preprocessing import LabelBinarizer
le = LabelBinarizer()

for x in colname[:-1]:
    student[x] = le.fit_transform(student[x])

    le_name_mapping  = dict(zip(le.classes_,le.transform(le.classes_)))
    print('Feature',x)
    print('mapping',le_name_mapping)
    print('------------------------')
# Out:
# Feature gender
# mapping {np.str_('F'): array([0]), np.str_('M'): array([1])}
# ------------------------
# Feature StageID
# mapping {np.str_('HighSchool'): array([1, 0, 0]), np.str_('MiddleSchool'): array([0, 1, 0]), np.str_('lowerlevel'): array([0, 0, 1])}
# ------------------------
# Feature SectionID
# mapping {np.str_('A'): array([1, 0, 0]), np.str_('B'): array([0, 1, 0]), np.str_('C'): array([0, 0, 1])}
# ------------------------
# Feature Relation
# mapping {np.str_('Father'): array([0]), np.str_('Mum'): array([1])}
# ------------------------
# Feature Semester
# mapping {np.str_('F'): array([0]), np.str_('S'): array([1])}
# ------------------------
# Feature Topic
# ...

# %%
student
# Out:
#      gender  StageID  SectionID  Relation  Semester  Topic  raisedhands  \
# 0         1        0          1         0         0      0           15
# 1         1        0          1         0         0      0           20
# 2         1        0          1         0         0      0           10
# 3         1        0          1         0         0      0           30
# 4         1        0          1         0         0      0           40
# ..      ...      ...        ...       ...       ...    ...          ...
# 475       0        0          1         0         1      0            5
# 476       0        0          1         0         0      0           50
# 477       0        0          1         0         1      0           55
# 478       0        0          1         0         0      0           30
# 479       0        0          1         0         1      0           35
#
#      VisITedResources  AnnouncementsView  Discussion  \
# ...

# %%
student['Class'] = student['Class'].map({"L":0,"M":1,"H":2})

# %%
student
# Out:
#      gender  StageID  SectionID  Relation  Semester  Topic  raisedhands  \
# 0         1        0          1         0         0      0           15
# 1         1        0          1         0         0      0           20
# 2         1        0          1         0         0      0           10
# 3         1        0          1         0         0      0           30
# 4         1        0          1         0         0      0           40
# ..      ...      ...        ...       ...       ...    ...          ...
# 475       0        0          1         0         1      0            5
# 476       0        0          1         0         0      0           50
# 477       0        0          1         0         1      0           55
# 478       0        0          1         0         0      0           30
# 479       0        0          1         0         1      0           35
#
#      VisITedResources  AnnouncementsView  Discussion  \
# ...

# %%
sns.set()
Class_plot= student['Class'].value_counts().plot(kind ='bar')
plt.xlabel("Performance")
plt.ylabel('count')
plt.xticks(rotation=360)
plt.show()

# %%
student['Class'].value_counts().plot(kind = 'pie',autopct="%.2f%%")
plt.ylabel(" ") ;

# %%
X = student.values[:,0:-1]
Y = student.values[:,-1]

# %%
print(X.shape)
print(Y.shape)
# Out:
# (480, 12)
# (480,)

# %%
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()

scaler.fit(X)
X = scaler.transform(X)
# X = scaler.fit_transform(X)
# print(X)

# %%
from sklearn.model_selection import train_test_split
# Split the data into test and train
X_train,X_test,Y_train,Y_test = train_test_split( X, Y , test_size=0.2 , random_state=10)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (384, 12)
# (384,)
# (96, 12)
# (96,)

# %%
from sklearn.linear_model import LogisticRegression
Classifier = LogisticRegression()
Classifier.fit(X_train, Y_train)

Y_pred = Classifier.predict(X_test)
print(Y_pred)
# Out:
# [2 1 1 0 2 2 2 2 1 0 1 1 2 1 1 1 0 2 1 1 0 1 0 2 1 0 2 2 1 2 1 2 0 2 1 0 1
#  1 0 2 1 0 1 0 1 1 2 1 1 2 1 0 2 1 1 2 2 0 1 2 2 0 2 1 1 1 1 2 0 2 1 0 1 1
#  1 1 0 0 1 2 0 2 0 0 1 2 1 2 2 1 2 0 1 1 2 1]

# %%
np.set_printoptions(suppress= True)
Y_pred_prob = Classifier.predict_proba(X_test)
Y_pred_prob
# Out:
# array([[0.00540585, 0.38343952, 0.61115463],
#        [0.11474704, 0.7852034 , 0.10004956],
#        [0.16780235, 0.81439552, 0.01780212],
#        [0.72380078, 0.26756634, 0.00863288],
#        [0.00481491, 0.49702664, 0.49815845],
#        [0.00025029, 0.22792442, 0.77182529],
#        [0.00357921, 0.44816823, 0.54825256],
#        [0.00126225, 0.28825051, 0.71048724],
#        [0.47614835, 0.51900049, 0.00485116],
#        [0.95626746, 0.04360042, 0.00013212],
#        [0.00128625, 0.71053013, 0.28818362],
#        [0.36923687, 0.60844587, 0.02231726],
#        [0.00422798, 0.49620699, 0.49956503],
#        [0.07923054, 0.70065679, 0.22011267],
#        [0.00725509, 0.77414033, 0.21860458],
#        [0.00317732, 0.58014764, 0.41667503],
#        [0.95066458, 0.04914082, 0.00019459],
#        [0.00140991, 0.19239488, 0.80619521],
#        [0.00962672, 0.90595645, 0.08441683],
#        [0.00337376, 0.71675814, 0.2798681 ],
#        [0.86819964, 0.13124435, 0.00055601],
# ...

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
cfm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cfm, annot = True, fmt = 'g' , cbar = False, cmap = 'BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()
print("Classification report:")

print(classification_report(Y_test,Y_pred))

acc=accuracy_score(Y_test,Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89        23
#            1       0.79      0.68      0.73        50
#            2       0.55      0.74      0.63        23
#
#     accuracy                           0.74        96
#    macro avg       0.75      0.76      0.75        96
# weighted avg       0.76      0.74      0.74        96
#
# Accuracy of the model:  0.7395833333333334

# %%
# print the scores on training and test set

print('Training set score: {:.4f}'.format(Classifier.score(X_train, Y_train)))

print('Test set score: {:.4f}'.format(Classifier.score(X_test, Y_test)))
# Out:
# Training set score: 0.7604
# Test set score: 0.7396

# %%
#predicting using the Decision_Tree_Classifier
from sklearn.tree import DecisionTreeClassifier

model_DecisionTree = DecisionTreeClassifier(criterion="gini",random_state=10)

#fit the model on the data and predict the values
model_DecisionTree.fit(X_train,Y_train)

Y_pred = model_DecisionTree.predict(X_test)
#print(Y_pred)
#print(list(zip(Y_test,Y_pred)))

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
 
cfm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cfm, annot=True, fmt='g', cbar=False, cmap='BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()

print("Classification report:")

print(classification_report(Y_test,Y_pred))

acc=accuracy_score(Y_test,Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.74      0.76        23
#            1       0.79      0.66      0.72        50
#            2       0.62      0.87      0.73        23
#
#     accuracy                           0.73        96
#    macro avg       0.73      0.76      0.73        96
# weighted avg       0.74      0.73      0.73        96
#
# Accuracy of the model:  0.7291666666666666

# %%
model_DecisionTree.score(X_train,Y_train)
# Out:
# 0.9973958333333334

# %%
# print the scores on training and test set
print('Training set score: {:.4f}'.format(model_DecisionTree.score(X_train, Y_train)))

print('Test set score: {:.4f}'.format(model_DecisionTree.score(X_test, Y_test)))
# Out:
# Training set score: 0.9974
# Test set score: 0.7292

# %%
print(list(zip(student.columns[0:-1],model_DecisionTree.feature_importances_)))
# Out:
# [('gender', np.float64(0.0457035272114482)), ('StageID', np.float64(0.009649307474691688)), ('SectionID', np.float64(0.009316447272651652)), ('Relation', np.float64(0.03184065887342196)), ('Semester', np.float64(0.0031054824242172166)), ('Topic', np.float64(0.02122373294098227)), ('raisedhands', np.float64(0.13766997498944183)), ('VisITedResources', np.float64(0.32501672864787307)), ('AnnouncementsView', np.float64(0.1277633544811367)), ('Discussion', np.float64(0.062345480791066984)), ('ParentschoolSatisfaction', np.float64(0.01091355251939193)), ('StudentAbsenceDays', np.float64(0.21545175237367642))]

# %%
sample=pd.DataFrame()

sample["Column"]=student.columns[0:-1]
sample["Imp value"]=model_DecisionTree.feature_importances_

sample.sort_values("Imp value",ascending=False)
# Out:
#                       Column  Imp value
# 7           VisITedResources   0.325017
# 11        StudentAbsenceDays   0.215452
# 6                raisedhands   0.137670
# 8          AnnouncementsView   0.127763
# 9                 Discussion   0.062345
# 0                     gender   0.045704
# 3                   Relation   0.031841
# 5                      Topic   0.021224
# 10  ParentschoolSatisfaction   0.010914
# 1                    StageID   0.009649
# 2                  SectionID   0.009316
# 4                   Semester   0.003105

# %%
plt.figure(figsize=(30,20))

from sklearn import tree

tree.plot_tree(model_DecisionTree.fit(X_train, Y_train));

# %%
from sklearn import tree
with open(r"model_DecisionTree.txt", "w") as f:

    f = tree.export_graphviz(model_DecisionTree, feature_names=student.columns[0:-1],
                             out_file=f)

#generate the file and upload the code in webgraphviz.com to plot the decision tree

# %%
#predicting using the Decision_Tree_Classifier
from sklearn.tree import DecisionTreeClassifier

model_DecisionTree = DecisionTreeClassifier(criterion="gini",random_state=10,
                                           splitter="best",min_samples_leaf=5,
                                           max_depth=10)

#fit the model on the data and predict the values
model_DecisionTree.fit(X_train,Y_train)

Y_pred = model_DecisionTree.predict(X_test)
#print(Y_pred)
#print(list(zip(Y_test,Y_pred)))

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

cfm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cfm, annot=True, fmt='g', cbar=False, cmap='BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()

print("Classification report:")

print(classification_report(Y_test,Y_pred))

acc=accuracy_score(Y_test,Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82        23
#            1       0.80      0.72      0.76        50
#            2       0.63      0.83      0.72        23
#
#     accuracy                           0.76        96
#    macro avg       0.76      0.78      0.76        96
# weighted avg       0.77      0.76      0.76        96
#
# Accuracy of the model:  0.7604166666666666

# %%
# print the scores on training and test set

print('Training set score: {:.4f}'.format(model_DecisionTree.score(X_train, Y_train)))

print('Test set score: {:.4f}'.format(model_DecisionTree.score(X_test, Y_test)))
# Out:
# Training set score: 0.8438
# Test set score: 0.7604

# %%
### utvilizing r3esults from feature importance for the model tuning 
stuent_new = student.drop(["Relation","StageID","ParentschoolSatisfaction"],axis =1 )
stuent_new
# Out:
#      gender  SectionID  Semester  Topic  raisedhands  VisITedResources  \
# 0         1          1         0      0           15                16
# 1         1          1         0      0           20                20
# 2         1          1         0      0           10                 7
# 3         1          1         0      0           30                25
# 4         1          1         0      0           40                50
# ..      ...        ...       ...    ...          ...               ...
# 475       0          1         1      0            5                 4
# 476       0          1         0      0           50                77
# 477       0          1         1      0           55                74
# 478       0          1         0      0           30                17
# 479       0          1         1      0           35                14
#
#      AnnouncementsView  Discussion  StudentAbsenceDays  Class
# ...

# %%
# Splitting the data 
X_n = stuent_new.values[:,:-1]
Y_n = stuent_new.values[:,-1]

# %%
print(X_n.shape)
print(Y_n.shape)
# Out:
# (480, 9)
# (480,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(X_n)
X_n = scaler.transform(X_n)
#X=scaler.fit_transform(X)
#print(X)

# %%
from sklearn.model_selection import train_test_split

#Split the data into test and train
X_train, X_test, Y_train, Y_test = train_test_split(X_n, Y_n, test_size=0.2,
                                                    random_state=10)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (384, 9)
# (384,)
# (96, 9)
# (96,)

# %%
from sklearn.linear_model import LogisticRegression
#create a model
classifier=LogisticRegression()
#fitting training data to the model
classifier.fit(X_train,Y_train)

Y_pred=classifier.predict(X_test)
print(Y_pred)
# Out:
# [1 1 1 0 1 2 1 2 0 0 2 1 1 1 1 1 0 2 1 2 0 1 0 2 1 0 2 1 1 2 2 1 0 2 2 0 1
#  1 0 1 1 0 1 0 1 2 2 1 1 2 1 0 1 1 1 2 2 0 1 2 2 0 1 1 1 1 1 2 0 2 1 0 1 1
#  1 1 0 0 2 2 0 2 0 0 1 2 1 2 2 1 1 0 1 1 1 1]

# %%
np.set_printoptions(suppress= True)
Y_pred_prob=classifier.predict_proba(X_test)
Y_pred_prob
# Out:
# array([[0.01290641, 0.61888128, 0.36821231],
#        [0.08616481, 0.63668014, 0.27715504],
#        [0.20417771, 0.75737383, 0.03844845],
#        [0.69130867, 0.28638298, 0.02230836],
#        [0.01041614, 0.71526366, 0.2743202 ],
#        [0.00018363, 0.19088443, 0.80893194],
#        [0.00623172, 0.58129312, 0.41247516],
#        [0.00106393, 0.28130658, 0.71762949],
#        [0.52320432, 0.47032136, 0.00647432],
#        [0.94298686, 0.05646432, 0.00054882],
#        [0.00054205, 0.38656956, 0.61288838],
#        [0.2984196 , 0.63302744, 0.06855297],
#        [0.00848093, 0.69054931, 0.30096976],
#        [0.06321009, 0.7174877 , 0.21930221],
#        [0.01079355, 0.86745193, 0.12175453],
#        [0.00210317, 0.4999781 , 0.49791873],
#        [0.93809626, 0.06141511, 0.00048862],
#        [0.00391153, 0.35548327, 0.6406052 ],
#        [0.00623846, 0.68387834, 0.3098832 ],
#        [0.00158019, 0.47422341, 0.5241964 ],
#        [0.90503437, 0.09446844, 0.00049719],
# ...

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

cfm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cfm, annot=True, fmt='g', cbar=False, cmap='BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()


print("Classification report:")

print(classification_report(Y_test,Y_pred))

acc=accuracy_score(Y_test,Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87        23
#            1       0.77      0.72      0.74        50
#            2       0.58      0.65      0.61        23
#
#     accuracy                           0.74        96
#    macro avg       0.74      0.75      0.74        96
# weighted avg       0.75      0.74      0.74        96
#
# Accuracy of the model:  0.7395833333333334

# %%
#predicting using the Decision_Tree_Classifier
from sklearn.tree import DecisionTreeClassifier

model_DecisionTree = DecisionTreeClassifier(criterion="gini",random_state=10)

#fit the model on the data and predict the values
model_DecisionTree.fit(X_train,Y_train)

Y_pred = model_DecisionTree.predict(X_test)
#print(Y_pred)
#print(list(zip(Y_test,Y_pred)))

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
 
cfm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cfm, annot=True, fmt='g', cbar=False, cmap='BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()

print("Classification report:")

print(classification_report(Y_test,Y_pred))

acc=accuracy_score(Y_test,Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81        23
#            1       0.74      0.50      0.60        50
#            2       0.45      0.74      0.56        23
#
#     accuracy                           0.64        96
#    macro avg       0.66      0.69      0.65        96
# weighted avg       0.68      0.64      0.64        96
#
# Accuracy of the model:  0.6354166666666666

# %%
# print the scores on training and test set

print('Training set score: {:.4f}'.format(model_DecisionTree.score(X_train, Y_train)))

print('Test set score: {:.4f}'.format(model_DecisionTree.score(X_test, Y_test)))
# Out:
# Training set score: 0.9974
# Test set score: 0.6354

# %%
from sklearn.ensemble import RandomForestClassifier

model_RandomForest = RandomForestClassifier(n_estimators=100,
                                               random_state=10,bootstrap=True)

model_DecisionTree.fit(X_train,Y_train)
Y_pred= model_DecisionTree.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

cfm=confusion_matrix(Y_test,Y_pred)
sns.heatmap(cfm, annot=True, fmt='g', cbar=False, cmap='BuPu')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()


print("Classification report:")

print(classification_report(Y_test,Y_pred))

acc=accuracy_score(Y_test,Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81        23
#            1       0.74      0.50      0.60        50
#            2       0.45      0.74      0.56        23
#
#     accuracy                           0.64        96
#    macro avg       0.66      0.69      0.65        96
# weighted avg       0.68      0.64      0.64        96
#
# Accuracy of the model:  0.6354166666666666

# %%
# print the scores on training and test set

print('Training set score: {:.4f}'.format(model_DecisionTree.score(X_train, Y_train)))

print('Test set score: {:.4f}'.format(model_DecisionTree.score(X_test, Y_test)))
# Out:
# Training set score: 0.9974
# Test set score: 0.6354
